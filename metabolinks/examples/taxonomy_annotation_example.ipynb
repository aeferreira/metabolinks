# %% [markdown]
# ## Example for the retrieval of BRITE/KeGG and LIPIDMAPS compound taxonomy.

# %%
import time

from metabolinks import read_MassTRIX

# %% [markdown]
# ### Read, clean and check a MassTRIX file with identification results.
#
# This file is in the MassTRIX "compact" format (one peak, several compounds per line)

# %%
start_time = time.time()

testfile_name = '../data/MassTRIX_output.tsv'

df = read_MassTRIX(testfile_name)
df = df.cleanup_cols() # removes uniqueID and 'isotopes' columns

print ("File {} was read\n".format(testfile_name))
df.info() # assert that there are 15 entries and 24 - 12 = 12 columns
df.head()
# Out:
# File ../data/MassTRIX_output.tsv was read
#
# <class 'metabolinks.masstrix.MassTRIXResults'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 12 columns):
# raw_mass                      15 non-null float64
# peak_height                   15 non-null float64
# corrected_mass                15 non-null float64
# npossible                     15 non-null int64
# KEGG_mass                     15 non-null object
# ppm                           15 non-null object
# KEGG_cid                      15 non-null object
# KEGG_formula                  15 non-null object
# KEGG_name                     15 non-null object
# KEGG Pathways                 13 non-null object
# KEGG Pathways descriptions    13 non-null object
# Compound in Organism(X)       13 non-null object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.5+ KB
#     raw_mass  peak_height  corrected_mass  npossible  \
# 0  133.08577          0.0      132.078494         26
# 1  149.01145          0.0      110.048291          3
# 2  177.00634          0.0      138.043181          4
# 3  189.04265          0.0      150.079491          1
# 4  203.05828          0.0      164.095121          3
#
#                                            KEGG_mass  \
# 0  133.085920710401#133.085920710401#133.08592071...
# 1  149.011172241631#149.011172241631#149.01117224...
# 2  177.006086861191#177.006086861191#177.00608686...
# 3                                        189.0424724
# 4  203.057968967081#203.058122434051#203.05812243...
#
#                                                  ppm  \
# 0  -1.1324306198618#-1.1324306198618#-1.132430619...
# 1  1.86400688677955#1.86400688677955#1.8640068867...
# 2  1.43011153725101#1.43011153725101#1.4301115372...
# 3                                        0.939629703
# 4  1.53174211364742#0.775964166523288#0.775964166...
#
#                                             KEGG_cid  \
# 0  C03264#C03499#C06103#C07834#HMDB00317#HMDB0040...
# 1                            C02560#C05130#HMDB03905
# 2                  C00785#C02126#HMDB00301#HMDB02730
# 3                                             C17512
# 4                            C00604#C11224#HMDB12246
#
#                                         KEGG_formula  \
# 0  C6H12O3#C6H12O3#C6H12O3#C6H12O3#C6H12O3#C6H12O...
# 1                            C5H6N2O#C5H6N2O#C5H6N2O
# 2                C6H6N2O2#C6H6N2O2#C6H6N2O2#C6H6N2O2
# 3                                           C8H10N2O
# 4                          C12H8N2#C9H12N2O#C9H12N2O
#
#                                            KEGG_name  \
# 0  D-2-Hydroxyisocaproate ([M+H]+)#Ethyl (R)-3-hy...
# 1  N-Acetylimidazole ([M+K39]+)#Imidazole-4-aceta...
# 2  Urocanate;Urocanic acid ([M+K39]+)#4-Nitroanil...
# 3  N-Methylanthranilamide;N-Methyl-2-aminobenzami...
# 4  1,10-Phenanthroline;o-Phenanthroline ([M+Na]+)...
#
#                                        KEGG Pathways  \
# 0  null#null#ko00930#null#null#null#null#null#nul...
# 1                                  null#ko00340#null
# 2                     ko00340;ko01100#null#null#null
# 3                                                NaN
# 4                                     null#null#null
#
#                           KEGG Pathways descriptions  \
# 0  null#null#;Caprolactam degradation#null#null#n...
# 1                    null#;Histidine metabolism#null
# 2  ;Histidine metabolism;Metabolic pathways#null#...
# 3                                                NaN
# 4                                     null#null#null
#
#                              Compound in Organism(X)
# 0  null#null#null#null#null#null#null#null#null#n...
# 1                                     null#null#null
# 2                                null#null#null#null
# 3                                                NaN
# 4                                     null#null#null

# %% [markdown]
# ### Annotate results with compound taxonomy.
#
# (Use *trace=True* as an argument to activate tracing of annotations)

# %%
print ('Starting annotating...\n')

df = df.insert_taxonomy()

elapsed_time = time.time() - start_time
m, s = divmod(elapsed_time, 60)
print ("Finished in " + "%02dm%02ds" % (m, s))
# Out:
# Starting annotating...
#
#
# Loading local DBs
# 100.0% done
# 100.0% done
# 100.0% done
# 100.0% done
# 100.0% done
# 100.0% done
# 100.0% done
# 100.0% done
# 100.0% done
# 100.0% done
# 100.0% done
# 100.0% done
# 100.0% done
# 100.0% done
# 100.0% done
#
# Done! 78 ids processed. 60 DB lookups
# updating local Kegg DB
#
# Done
# Finished in 00m10s

# %%
# check result
df.info()
df[['trans_KEGG_Ids',
    'trans_LipidMaps_Ids',
    'Major Class', 'Class',
    'Secondary Class',
    'Tertiary Class',
    'KNApSAcK']].head(10)
# Out:
# <class 'metabolinks.masstrix.MassTRIXResults'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 19 columns):
# raw_mass                      15 non-null float64
# peak_height                   15 non-null float64
# corrected_mass                15 non-null float64
# npossible                     15 non-null int64
# KEGG_mass                     15 non-null object
# ppm                           15 non-null object
# KEGG_cid                      15 non-null object
# KEGG_formula                  15 non-null object
# KEGG_name                     15 non-null object
# KEGG Pathways                 13 non-null object
# KEGG Pathways descriptions    13 non-null object
# Compound in Organism(X)       13 non-null object
# trans_KEGG_Ids                15 non-null object
# trans_LipidMaps_Ids           15 non-null object
# Major Class                   15 non-null object
# Class                         15 non-null object
# Secondary Class               15 non-null object
# Tertiary Class                15 non-null object
# KNApSAcK                      15 non-null object
# dtypes: float64(3), int64(1), object(15)
# memory usage: 2.3+ KB
#                                       trans_KEGG_Ids  \
# 0  C03264#C03499#C06103#C07834#HMDB00317#HMDB0040...
# 1                               C02560#C05130#C05130
# 2                     C00785#C02126#C00785#HMDB02730
# 3                                             C17512
# 4                            C00604#C11224#HMDB12246
# 5  C01056#C03043#C16569#HMDB01240#HMDB01329#HMDB0...
# 6              C05636#C05638#C12033#C05638#HMDB13319
# 7                               C06537#C14742#C15042
# 8                               C01748#C06538#C13311
# 9                                      C14274#C14718
#
#                                  trans_LipidMaps_Ids  \
# 0  LMFA01050402#C03499#LMFA01050015#C07834#HMDB00...
# 1                            C02560#C05130#HMDB03905
# 2                  C00785#C02126#HMDB00301#HMDB02730
# 3                                             C17512
# 4                            C00604#C11224#HMDB12246
# 5  C01056#C03043#C16569#HMDB01240#HMDB01329#HMDB0...
# 6           C05636#C05638#C12033#HMDB04076#HMDB13319
# 7                               C06537#C14742#C15042
# 8                               C01748#C06538#C13311
# 9                                      C14274#C14718
#
#                                          Major Class  \
# 0  Lipids [BR:br08002]#Anatomical Therapeutic Che...
# 1
# 2
# 3
# 4                            Pesticides [BR:br08007]
# 5                            Pesticides [BR:br08007]
# 6
# 7                           Carcinogens [BR:br08008]
# 8               Phytochemical compounds [BR:br08003]
# 9
#
#                                                Class  \
# 0  N NERVOUS SYSTEM#Fatty Acyls [FA]#FA  Fatty acyls
# 1
# 2
# 3
# 4                                Obsolete pesticides
# 5                                         Pesticides
# 6
# 7  Group 3: Not classifiable as to its carcinogen...
# 8                                          Alkaloids
# 9
#
#                                      Secondary Class  \
# 0  FA01 Fatty Acids and Conjugates#Fatty Acids an...
# 1
# 2
# 3
# 4                                         Herbicides
# 5                                         Herbicides
# 6
# 7                                          Compounds
# 8  Alkaloids derived from tryptophan and anthrani...
# 9
#
#                                       Tertiary Class KNApSAcK
# 0  N05C HYPNOTICS AND SEDATIVES#FA0105 Hydroxy fa...
# 1
# 2
# 3
# 4                              Phenylurea herbicides
# 5                                  Uracil herbicides
# 6
# 7                     C14742  N-Nitrosodiphenylamine
# 8                                   Indole alkaloids  Plantae
# 9

# %% [markdown]
# ### Export the annotated dataframe into a MS-Excel file
#
# Use the same name as the MassTRIX .tsv data file, replacing tail with '_raw.xlsx'

# %%
out_fname = testfile_name[:-4]+'_compound_taxa.xlsx'

df.to_excel(out_fname, header=True, index=False)

print ("File {} created".format(out_fname))

# %% [markdown]
# ### Annotate results with compound taxonomy but, this time, use a black list of BRITE ids.
#
# #### Also, use *trace=True* as an argument to activate tracing of annotations

# %%
start_time = time.time()

print ('Starting annotating...\n')

df = read_MassTRIX(testfile_name)
df = df.cleanup_cols() # removes uniqueID and 'isotopes' columns

print ("File {} was read\n".format(testfile_name))

black_list_fname = '../data/blacklist.txt'

df = df.insert_taxonomy(brite_blacklist=black_list_fname, trace=True)

elapsed_time = time.time() - start_time
m, s = divmod(elapsed_time, 60)
print ("Finished in " + "%02dm%02ds" % (m, s))

# %%
# check result
df[['trans_KEGG_Ids',
    'trans_LipidMaps_Ids',
    'Major Class', 'Class',
    'Secondary Class',
    'Tertiary Class',
    'KNApSAcK']].head(10)
