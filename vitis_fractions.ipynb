# %%
from peak_alignment import workflow

# %%
ppmtol = 1.0

# %%
indir = "vitis_fractions/"
infiles = ['ESIneg_replicates_vitis_feb2016_recal.xlsx'] #, 'ESIpos_replicates_vitis_feb2016.xlsx']
snames = ['ACN', 'H2O', 'MeOH', 'Org']
locs = {'23': 'B,C',
        '24': 'E,F',
        '25': 'H,I'}

# %%
for fname in infiles:
    excel_in_name = indir + fname
    excel_out_name = indir + 'aligned_' + fname
    print (excel_in_name)
    print (excel_out_name)
    workflow(excel_in_name, excel_out_name, snames, locs, ppmtol, aligned_dir=False)
# Out:
# vitis_fractions/ESIneg_replicates_vitis_feb2016_recal.xlsx
# vitis_fractions/aligned_ESIneg_replicates_vitis_feb2016_recal.xlsx
# ...
# Processing sheet ACN, form file vitis_fractions/ESIneg_replicates_vitis_feb2016_recal.xlsx
#
#
# - Reading data frames ---------------
# File "vitis_fractions/ESIneg_replicates_vitis_feb2016_recal.xlsx":
# Sheet"ACN":
# 24 | shape = (97, 2)
# 23 | shape = (86, 2)
# 25 | shape = (111, 2)
#
# - Tagging with replicate names ------
# Data were tagged (with new col):
# 24 | shape = (97, 3)
# 23 | shape = (86, 3)
# 25 | shape = (111, 3)
#
# - Merging ---------------------------
# Data frames were merged. | shape = (294, 3)
# - Inserting group labels ------------
# Classification column inserted!
# Dataframe shape = (294, 4), last group: 180
#
# - Grouping --------------------------
# Alignment done! # groups (compounds) = 181
#
# - Splitting intensities -------------
# Done!
#
# - Assembling results ----------------
# Results data frame created.
# ...
#
# ...
